# %%
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dic_1 = {
    'Lojas':['A','B','C','D'],
    'Estoque': [500,100,300,600],
    'Chave': ['AA','BB','CC','DD']
}
df_Estoque = pd.DataFrame(dic_1)
df_Estoque.head()
# Out:
#   Lojas  Estoque Chave
# 0     A      500    AA
# 1     B      100    BB
# 2     C      300    CC
# 3     D      600    DD

# %%
dic_Vendas = {
    'Lojas':['A','B','C','D'],
    'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],    'Mar': [150, 100, 200, 80],    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250],
    'Chave': ['AA','BB','CC','DD']
    }

# %%
vendas_df = pd.DataFrame(dic_Vendas)
vendas_df.head()
# Out:
#   Lojas  Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez Chave
# 0     A  100  120  150  180  220  230  250  260  240  220  400  300    AA
# 1     B   80   90  100  110  190  150  170  180  160  140  220  350    BB
# 2     C  150  170  200  230  350  280  300  310  290  270  350  400    CC
# 3     D   50   60   80   90  200  120  140  150  130  110  190  250    DD

# %%
df_ecommerce = pd.merge(df_Estoque,vendas_df,how='inner',on= 'Chave')

# %%
df_vendas = vendas_df.T
df_vendas.head()
# Out:
#          0    1    2   3
# Lojas    A    B    C   D
# Jan    100   80  150  50
# Fev    120   90  170  60
# Mar    150  100  200  80
# Abr    180  110  230  90

# %%
df_ecommerce.head()
# Out:
#   Lojas_x  Estoque Chave Lojas_y  Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  \
# 0       A      500    AA       A  100  120  150  180  220  230  250  260  240
# 1       B      100    BB       B   80   90  100  110  190  150  170  180  160
# 2       C      300    CC       C  150  170  200  230  350  280  300  310  290
# 3       D      600    DD       D   50   60   80   90  200  120  140  150  130
#
#    Out  Nov  Dez
# 0  220  400  300
# 1  140  220  350
# 2  270  350  400
# 3  110  190  250

# %%
df_ecommerce.drop('Chave',axis=1,inplace=True)

# %%
df_ecommerce.drop('Lojas_y',axis=1,inplace=True)

# %%
df_ecommerce.head()
# Out:
#   Lojas_x  Estoque  Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# 0       A      500  100  120  150  180  220  230  250  260  240  220  400  300
# 1       B      100   80   90  100  110  190  150  170  180  160  140  220  350
# 2       C      300  150  170  200  230  350  280  300  310  290  270  350  400
# 3       D      600   50   60   80   90  200  120  140  150  130  110  190  250

# %%
df_ecommerce.set_index(['Lojas_x'])
# Out:
#          Estoque  Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# Lojas_x
# A            500  100  120  150  180  220  230  250  260  240  220  400  300
# B            100   80   90  100  110  190  150  170  180  160  140  220  350
# C            300  150  170  200  230  350  280  300  310  290  270  350  400
# D            600   50   60   80   90  200  120  140  150  130  110  190  250

# %%
plt.bar(df_ecommerce['Lojas_x'],df_ecommerce['Jan'],color = 'red')
# Out:
# <BarContainer object of 4 artists>

# %%
# Criando a figura
fig, axs = plt.subplots(1, 2, figsize=(15,5)) # cria uma figura e armazena na variável axs
# axs - ax - é a abreviação de axes
# s é de subplot 

# Subplot 1: Gráfico de barras
axs[0].bar(df_ecommerce['Lojas_x'], df_ecommerce['Estoque'])
axs[0].set_title('Estoque de produtos')
axs[0].set_xlabel('Lojas')
axs[0].set_ylabel('Quantidade de produtos')

axs[0].grid()
# Subplot 2: Boxplot
axs[1].bar(df_ecommerce['Lojas_x'], df_ecommerce['Jan'])
axs[1].set_title('Histórico de vendas')
axs[1].set_xlabel('Lojas')
axs[1].set_ylabel('Quantidade de produtos')
# Out:
# Text(0, 0.5, 'Quantidade de produtos')

# %%
# Subplot 1: Gráfico de linhas
fig, axs = plt.subplots(1, 2, figsize=(15,5)) # cria uma figura e armazena na variável axs
axs[0].plot(df_ecommerce['Lojas_x'], df_ecommerce['Jan'])
axs[0].set_title('Histórico de vendas')
axs[0].set_xlabel('Lojas')
axs[0].set_ylabel('Quantidade de produtos')

axs[0].grid()
# Subplot 2: Boxplot
axs[1].plot(df_ecommerce['Lojas_x'], df_ecommerce['Fev'])
axs[1].set_title('Histórico de vendas')
axs[1].set_xlabel('Lojas')
axs[1].set_ylabel('Quantidade de produtos')
# Out:
# Text(0, 0.5, 'Quantidade de produtos')

# %%
sns.barplot(x='Fev', y='Lojas_x', data=df_ecommerce, orient='h')
plt.title('Vendas em Fevereiro')
plt.show()

# %%
data = {'Categoria': ['A', 'B', 'C', 'D'],
        'Valores': [4, 9, 2, 7]}

# Convertendo em DataFrame
df = pd.DataFrame(data)

# Plotando o gráfico de barras horizontal
sns.barplot(x='Valores', y='Categoria', data=df, orient='h')
# Out:
# <Axes: xlabel='Valores', ylabel='Categoria'>

# %%
df_novo = df_ecommerce.T
df_novo.head()
# Out:
#            0    1    2    3
# Lojas_x    A    B    C    D
# Estoque  500  100  300  600
# Jan      100   80  150   50
# Fev      120   90  170   60
# Mar      150  100  200   80

# %%
import pandas as pd

# Dados de estoque
dic_1 = {
    'Lojas': ['A', 'B', 'C', 'D'],
    'Estoque': [500, 100, 300, 600],
    'Chave': ['AA', 'BB', 'CC', 'DD']
}
df_estoque = pd.DataFrame(dic_1)

# Dados de vendas
dic_vendas = {
    'Lojas': ['A', 'B', 'C', 'D'],
    'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abril': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 2980, 120],
    'Jul': [150, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 200, 350, 190],
    'Dez': [300, 350, 400, 250],
    'Chave': ['AA', 'BB', 'CC', 'DD']
}
df_vendas = pd.DataFrame(dic_vendas)

# Unindo os dois DataFrames pela coluna 'Chave'
df_final = pd.merge(df_estoque, df_vendas, on='Chave')

# Exibindo o DataFrame final
print(df_final)
# Out:
#   Lojas_x  Estoque Chave Lojas_y  Jan  Fev  Mar  Abril  Mai   Jun  Jul  Ago  \
# 0       A      500    AA       A  100  120  150    180  220   230  150  260
# 1       B      100    BB       B   80   90  100    110  190   150  170  180
# 2       C      300    CC       C  150  170  200    230  350  2980  300  310
# 3       D      600    DD       D   50   60   80     90  200   120  140  150
#
#    Set  Out  Nov  Dez
# 0  240  220  400  300
# 1  160  140  200  350
# 2  290  270  350  400
# 3  130  110  190  250

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dados de vendas
dic_vendas = {
    'Lojas': ['A', 'B', 'C', 'D'],
    
    'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abril': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 290, 120],
    'Jul': [150, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 200, 350, 190],
    'Dez': [300, 350, 400, 250],
    'Chave': ['AA', 'BB', 'CC', 'DD']
    
}
df_vendas = pd.DataFrame(dic_vendas)

# Definindo os meses para o eixo x
meses = ['Jan', 'Fev', 'Mar', 'Abril', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']

# Configurando o gráfico
plt.figure(figsize=(10, 6))

# Iterando por cada loja para plotar seu histórico de vendas
for i, loja in enumerate(df_vendas['Lojas']):
    plt.plot(meses, df_vendas.iloc[i, 1:-1], label=f'Loja {loja}', marker='o')

# Adicionando títulos e rótulos
plt.title('Histórico de Vendas de Janeiro a Dezembro')
plt.xlabel('Meses')
plt.ylabel('Vendas')
plt.legend(title="Lojas")
plt.grid(True)

# Exibindo o gráfico
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
